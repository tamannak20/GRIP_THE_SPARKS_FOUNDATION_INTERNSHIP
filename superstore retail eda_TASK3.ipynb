# %% [markdown]
# <p style = 'font-size:18px;color:purple'> <b> Problem Statement : Perform 'Exploratory Data Analysis' on Dataset 'SampleSuperstore' </b> </p>
#
# <p style ='font-size:18px;color:black'>Author: Tamanna </b> </p>

# %% [markdown]
# <p style = 'font-size:18px;color:black'><b>Importing necessary lib</b> </p>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# <p style = 'font-size:18px;color:black'><b>reading the file </b> </p>

# %%
df =  pd.read_csv('SampleSuperstore.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# <p style = 'font-size:18px;color:orange'> we are having
# <ul><li>total number of columns : 12 </li>
# <li>total number of rows : 9993 </li>
# <li>total number of null values in each column : 0  </li>
# <li>data type for columns are object, int , float  </li></ul></p>

# %%
df_statistics = df.iloc[:,[9,10,11,12]]

# %%
print(df_statistics.head())
print('-'*40)
print(df_statistics.isna().sum())
# Out:
#       Sales  Quantity  Discount    Profit
# 0  261.9600         2      0.00   41.9136
# 1  731.9400         3      0.00  219.5820
# 2   14.6200         2      0.00    6.8714
# 3  957.5775         5      0.45 -383.0310
# 4   22.3680         2      0.20    2.5164
# ----------------------------------------
# Sales       0
# Quantity    0
# Discount    0
# Profit      0
# dtype: int64

# %%
statistical_summary = round(df_statistics.describe(),2)
print(statistical_summary)
# Out:
#           Sales  Quantity  Discount   Profit
# count   9994.00   9994.00   9994.00  9994.00
# mean     229.86      3.79      0.16    28.66
# std      623.25      2.23      0.21   234.26
# min        0.44      1.00      0.00 -6599.98
# 25%       17.28      2.00      0.00     1.73
# 50%       54.49      3.00      0.20     8.67
# 75%      209.94      5.00      0.20    29.36
# max    22638.48     14.00      0.80  8399.98

# %% [markdown]
# <p style = 'font-size:18px;color:orange'> statistical summary of the data :
# <ul><li>avergae sales value is 229.86 in addition it varies from min sales value is : 0.44 to max sales value: 22638.48 with variation of 623.25 from the mean </li>
# <li>avergae quantity  is around 4 in addition it varies from min quantity  : 1 to max quantity :14  with variation of 2 from the mean </li>
# <li>avergae discount was found to be 0.16 in addition it varies from min discount of : 0 to max discount of: .8 with variation of .21 from the mean </li>
# <li>avergae profit of 28.66 in addition it varies from min profit of : -6599.98 to max profit of : 8399.98 with variation of 234.26 from the mean  </li></ul></p>

# %% [markdown]
# <p style = 'font-size:18px;color:black'><b> total unique value and total duplicate value in the data set,</b> </p>

# %%
print(f'total duplicate values present in data : {df.duplicated().sum()}')
print()
print('-'*50)
print(df.nunique()) # checking for unique value present in the data set
# Out:
# total duplicate values present in data : 17
#
# --------------------------------------------------
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# <p style = 'font-size:18px;color:black'><b> total duplicate values present in the data set : 17</b> </p>

# %%
# droping duplicate values
print(f"shape of data set before removing duplicates : {df.shape}")
print()
print("-"*60)
print()
df.drop_duplicates(inplace=True)
print(f'shape of data set after removing duplicate : {df.shape}')
# Out:
# shape of data set before removing duplicates : (9994, 13)
#
# ------------------------------------------------------------
#
# shape of data set after removing duplicate : (9977, 13)

# %%
sns.pairplot(data=df)

# %% [markdown]
# <p style = 'font-size:18px;color:purple'><ul><li>from pair plot we can observe that postal code has no importance </li>
#     <li>there is a linear relation between sales and profit </li>
#     <li>most of the products are sold within 5000 Usd dollar </li>
#     <li>sale is more when discount is none as we increase discount sales reduces </li></ul></p>

# %%
sns.scatterplot(data=df,x='Sales',y='Quantity',color="pink")
plt.show()

# %% [markdown]
# <p style = 'font-size:18px;color:orange'> as we can see in the plot above almost all the quantity has been sold out within 5000 usd only few lies between 5000 to 10000 usd </p>

# %%
sns.scatterplot(data=df,y='Sales',x='Discount',color="green")
plt.show()

# %%
sns.scatterplot(data=df,x='Sales',y='Profit',color="purple")
plt.show()

# %% [markdown]
# <p style = 'font-size:18px;color:orange'> as we can see in the plot above almost all profit has been made when sales ranges between 0 to 5000 usd  </p>

# %% [markdown]
# <p style = 'font-size:18px;color:orange'> checking for outlier in numerical data sets </p>

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))
 
fig.suptitle('analysis of outliers using box plot in numerical data ')
 
sns.boxplot(ax=axes[0, 0], data=df, x='Sales' )
sns.boxplot(ax=axes[0, 1], data=df, x='Quantity')
sns.boxplot(ax=axes[1, 0], data=df, x='Discount')
sns.boxplot(ax=axes[1, 1], data=df, x='Profit')
# Out:
# <AxesSubplot:xlabel='Profit'>

# %% [markdown]
# <p style = 'font-size:18px;color:orange'> as we can see in each numerical plot we afre having outliers and it has to be addressed</p>

# %% [markdown]
# <p style = 'font-size:20px;color:black'> <b>removing outlier from the data set using IQR technique</b> </p>

# %%
def remove_outliers(colname):
    Q1 = np.percentile(df[colname],25,interpolation='midpoint')
    Q3 = np.percentile(df[colname],75,interpolation='midpoint')
    IQR = Q3-Q1
    print(f'first quartile : {Q1} \nthird quartile: {Q3}\nInter quartile range : {IQR}')
    print('-'*50)
    data_filter= (df[colname] >= Q1 - 1.5 * IQR) & (df_statistics[colname] <= Q3 + 1.5 * IQR)
    data_no_outlier = df[data_filter][colname]
    print(data_no_outlier)
    print('-'*50)
    print(f'checking null values if any present in the column {colname} : {data_no_outlier.isna().sum()}')
    
    sns.boxplot(data=data_no_outlier)
    plt.xlabel(colname)
remove_outliers('Sales')
# Out:
# first quartile : 17.3
# third quartile: 209.97
# Inter quartile range : 192.67
# --------------------------------------------------
# 0       261.960
# 2        14.620
# 4        22.368
# 5        48.860
# 6         7.280
#          ...
# 9989     25.248
# 9990     91.960
# 9991    258.576
# 9992     29.600
# 9993    243.160
# Name: Sales, Length: 8810, dtype: float64
# --------------------------------------------------
# checking null values if any present in the column Sales : 0
# C:\Users\taman\AppData\Local\Temp\ipykernel_6264\3264751163.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df[colname],25,interpolation='midpoint')
# ...

# %%
def remove_outliers(colname):
    Q1 = np.percentile(df[colname],25,interpolation='midpoint')
    Q3 = np.percentile(df[colname],75,interpolation='midpoint')
    IQR = Q3-Q1
    print(f'first quartile : {Q1} \nthird quartile: {Q3}\nInter quartile range : {IQR}')
    print('-'*50)
    data_filter= (df[colname] >= Q1 - 1.5 * IQR) & (df_statistics[colname] <= Q3 + 1.5 * IQR)
    data_no_outlier = df[data_filter][colname]
    print(data_no_outlier)
    print('-'*50)
    print(f'checking null values if any present in the column {colname} : {data_no_outlier.isna().sum()}')
    
    sns.boxplot(data=data_no_outlier)
    plt.xlabel(colname)
remove_outliers('Profit')
# Out:
# first quartile : 1.7262
# third quartile: 29.372
# Inter quartile range : 27.6458
# --------------------------------------------------
# 0       41.9136
# 2        6.8714
# 4        2.5164
# 5       14.1694
# 6        1.9656
#          ...
# 9988    55.6470
# 9989     4.1028
# 9990    15.6332
# 9991    19.3932
# 9992    13.3200
# Name: Profit, Length: 8096, dtype: float64
# --------------------------------------------------
# checking null values if any present in the column Profit : 0
# C:\Users\taman\AppData\Local\Temp\ipykernel_6264\823543885.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df[colname],25,interpolation='midpoint')
# ...

# %%
def remove_outliers(colname):
    Q1 = np.percentile(df[colname],25,interpolation='midpoint')
    Q3 = np.percentile(df[colname],75,interpolation='midpoint')
    IQR = Q3-Q1
    print(f'first quartile : {Q1} \nthird quartile: {Q3}\nInter quartile range : {IQR}')
    print('-'*50)
    data_filter= (df[colname] >= Q1 - 1.5 * IQR) & (df_statistics[colname] <= Q3 + 1.5 * IQR)
    data_no_outlier = df[data_filter][colname]
    print(data_no_outlier)
    print('-'*50)
    print(f'checking null values if any present in the column {colname} : {data_no_outlier.isna().sum()}')
    
    sns.boxplot(data=data_no_outlier)
    plt.xlabel(colname)
remove_outliers('Discount')
# Out:
# first quartile : 0.0
# third quartile: 0.2
# Inter quartile range : 0.2
# --------------------------------------------------
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.45
# 4       0.20
#         ...
# 9989    0.20
# 9990    0.00
# 9991    0.20
# 9992    0.00
# 9993    0.00
# Name: Discount, Length: 9122, dtype: float64
# --------------------------------------------------
# checking null values if any present in the column Discount : 0
# C:\Users\taman\AppData\Local\Temp\ipykernel_6264\4047285936.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df[colname],25,interpolation='midpoint')
# ...

# %%
def remove_outliers(colname):
    Q1 = np.percentile(df[colname],25,interpolation='midpoint')
    Q3 = np.percentile(df[colname],75,interpolation='midpoint')
    IQR = Q3-Q1
    print(f'first quartile : {Q1} \nthird quartile: {Q3}\nInter quartile range : {IQR}')
    print('-',50)
    data_filter= (df[colname] >= Q1 - 1.5 * IQR) & (df_statistics[colname] <= Q3 + 1.5 * IQR)
    data_no_outlier = df[data_filter][colname]
    print(data_no_outlier)
    print('-'*50)
    print(f'checking null values if any present in the column {colname} : {data_no_outlier.isna().sum()}')
    
    sns.boxplot(data=data_no_outlier)
    plt.xlabel(colname)
remove_outliers('Quantity')
# Out:
# first quartile : 2.0
# third quartile: 5.0
# Inter quartile range : 3.0
# - 50
# 0       2
# 1       3
# 2       2
# 3       5
# 4       2
#        ..
# 9989    3
# 9990    2
# 9991    2
# 9992    4
# 9993    2
# Name: Quantity, Length: 9807, dtype: int64
# --------------------------------------------------
# checking null values if any present in the column Quantity : 0
# C:\Users\taman\AppData\Local\Temp\ipykernel_6264\1105744387.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df[colname],25,interpolation='midpoint')
# C:\Users\taman\AppData\Local\Temp\ipykernel_6264\1105744387.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %% [markdown]
# <p style = 'font-size:18px;color:black'><b> checking for missing value if any using isna()</b> </p>

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.drop(['Postal Code'],axis=1,inplace=True)
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(df['Category'],df["Sales"],color='purple')
plt.xlabel('category')
plt.ylabel('sales')
plt.title('category wise sales ')
plt.show()

# %%
sns.barplot(palette='Set2',data=df,x='Category',y='Sales', hue='Region')
plt.show()

# %%
subcat_sale = round(df.groupby('Sub-Category')['Sales'].sum(),2)
subcat_sale_reset= subcat_sale.reset_index()

# %%
subcat_sale_df = subcat_sale_reset.pivot_table(index=None,columns='Sub-Category',values="Sales",aggfunc='sum')

# %%
subcat_profit = round((df.groupby('Sub-Category')['Profit'].sum()/df['Profit'].sum())*100,2)
subcat_profit_reset= subcat_profit.reset_index()
subcat_profit_df = subcat_profit_reset.pivot_table(index=None,columns='Sub-Category',values="Profit",aggfunc='sum')
subcat_Quantity = round(df.groupby('Sub-Category')['Quantity'].sum(),2)
subcat_Quantity_reset= subcat_Quantity.reset_index()
subcat_Quantity_df = subcat_Quantity_reset.pivot_table(index=None,columns='Sub-Category',values="Quantity",aggfunc='sum')

# %%
df_subcat = pd.concat([subcat_sale_df,subcat_profit_df,subcat_Quantity_df],axis=0)
df_subcat
# Out:
# Sub-Category  Accessories  Appliances       Art    Binders  Bookcases  \
# Sales           167380.32   107532.16  27107.03  203409.17  114880.00
# Profit              14.65        6.34      2.28      10.56      -1.21
# Quantity          2976.00     1729.00   2996.00    5971.00     868.00
#
# Sub-Category     Chairs    Copiers  Envelopes  Fasteners  Furnishings  \
# Sales         327777.76  149528.03   16476.40    3024.28     91683.02
# Profit             9.28      19.43       2.43       0.33         4.56
# Quantity        2351.00     234.00     906.00     914.00      3560.00
#
# Sub-Category    Labels   Machines     Paper     Phones    Storage  Supplies  \
# Sales         12444.91  189238.63  78224.14  330007.05  223843.61  46673.54
# Profit            1.93       1.18     11.86      15.55       7.43     -0.42
# Quantity       1396.00     440.00   5144.00    3289.00    3158.00    647.00
#
# Sub-Category     Tables
# Sales         206965.53
# Profit            -6.19
# ...

# %%
sns.countplot(data=df,x='Quantity',hue='Segment')
plt.legend(loc='upper right')
plt.show()

# %%
#obtaining percentage of each catgeory 
office_supplies_sales = df[df['Category'] == 'Office Supplies']['Sales']
Furniture_sales = df[df['Category'] == 'Furniture']['Sales']
Technology_sales = df[df['Category'] == 'Technology']['Sales']
total_sale = df["Sales"].sum()
perc_off_supp = (office_supplies_sales/total_sale)*100
perc_furniture = (Furniture_sales/total_sale)*100
perc_Tech_supp = (Technology_sales/total_sale)*100
off_sup = round(perc_furniture.sum(),2)
furniture_ = round(perc_off_supp.sum(),2)
tech_= round(perc_Tech_supp.sum(),2)
data = [off_sup,furniture_,tech_]
category =['Office_supply','furniture','tech']
explode = (0, 0.05, 0.05)
plt.pie(data,labels=category,autopct='%1.1f%%',explode=explode,colors=sns.color_palette('Set2'),pctdistance=1.2,labeldistance=0.4)
plt.title('sale breakage category wise ')
plt.show()

# %%
# which category is most profitable and is having highest sell 
cat_prof = round((df.groupby(['Category'])['Profit'].sum()/df['Profit'].sum())*100,2)
cat_sales = round(df.groupby(['Category'])['Sales'].sum(),2)
cat_pro_sale = pd.concat([cat_prof,cat_sales],axis=1)
cat_pro_sale
# Out:
#                  Profit      Sales
# Category
# Furniture          6.44  741306.31
# Office Supplies   42.75  718735.24
# Technology        50.82  836154.03

# %%
seg_profit = pd.DataFrame(round((df.groupby(['Segment'])[['Profit']].sum().sort_values('Profit',ascending=False)/df['Profit'].sum())*100,2))
seg_profit
# Out:
#              Profit
# Segment
# Consumer      46.82
# Corporate     32.12
# Home Office   21.06

# %%
sns.barplot(data=seg_profit,x=seg_profit.index,y="Profit",palette='rocket')
plt.show()

# %%
city_sale = pd.DataFrame(round((df.groupby(['City'])[['Sales']].sum().sort_values('Sales',ascending=False)/df['Sales'].sum())*100,2))

# %%
top_selling_city = city_sale.head()

# %%
sns.barplot(data=top_selling_city,x=top_selling_city.index,y="Sales",palette='BuGn')
plt.show()

# %%
ship_mode_data = df.groupby(['Ship Mode'])['Quantity'].sum()

# %%
sns.countplot(data=df, x='Ship Mode',palette='icefire')
plt.show()

# %%
seg_sell=round((df.groupby(['Segment'])['Sales'].sum())/df['Sales'].sum()*100,2)

# %%
seg_sell_df=pd.DataFrame(seg_sell)
seg_sell_df
# Out:
#              Sales
# Segment
# Consumer     50.55
# Corporate    30.75
# Home Office  18.70
